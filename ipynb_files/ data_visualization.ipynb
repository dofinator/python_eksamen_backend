# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from termcolor import colored as cl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/residence2.csv',sep=";", index_col=False)
df
# Out:
#           house_type  house_zip_code  house_rooms  house_square_meters  \
# 0              Villa            6400            5                  147
# 1      Ejerlejlighed            8000            2                   45
# 2              Villa            3740            4                  118
# 3              Villa            6710            4                  149
# 4              Villa            7500            6                  203
# ...              ...             ...          ...                  ...
# 27068          Villa            5690            7                  191
# 27069          Villa            5500            5                  163
# 27070          Villa            8500            7                  225
# 27071          Villa            7600            5                  228
# 27072          Villa            7790            6                  179
#
#        house_year  house_taxes house_energy  house_ground_area  house_price
# 0              19         2232            B               1063      2395000
# 1             111         2077            D                  0      2398000
# 2              55         1649            E                698      2400000
# 3              51         2236            E                667      2448000
# 4              45         2595            D               1037      2495000
# ...           ...          ...          ...                ...          ...
# 27068         123         1706            F               1034       695000
# 27069         106         1696            F                885      1098000
# 27070          47         2258            D                929      1595000
# 27071          66         2671            F               1554      1695000
# 27072          49         1190            F                843       595000
#
# [27073 rows x 9 columns]

# %%
label_enc =preprocessing.LabelEncoder()
df['house_type'] = label_enc.fit_transform(df['house_type'].astype(str))
# Encode the house energy from string to integer
df['house_energy'] = label_enc.fit_transform(df['house_energy'].astype(str))
# Set zip for more precise predictions 
df = df.loc[df['house_zip_code'].isin([2900, 2920, 2930, 2820, 2930, 2960, 2950])]


# Set type for more precise predictions
#df = df.loc[df['house_type'] == 2]

#Data


df.plot.scatter(x="house_square_meters", y="house_price");

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-ad39e03a5ffb> in <module>
# ----> 1 df.plot.pie(subplots=True);
#
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_core.py in pie(self, **kwargs)
#    1416         ):
#    1417             raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1418         return self(kind="pie", **kwargs)
#    1419
#    1420     def scatter(self, x, y, s=None, c=None, **kwargs):
#
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      58                 ax = plt.gca()
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      61     plot_obj.generate()
#      62     plot_obj.draw()
#
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, kind, **kwargs)
#    1461         data = data.fillna(value=0)
#    1462         if (data < 0).any().any():
# -> 1463             raise ValueError(f"{kind} doesn't allow negative values")
#    1464         MPLPlot.__init__(self, data, kind=kind, **kwargs)
#    1465
#
# ValueError: None doesn't allow negative values
