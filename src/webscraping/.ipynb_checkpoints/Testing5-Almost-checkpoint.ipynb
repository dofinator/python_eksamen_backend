# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# load the data set
df = pd.read_csv('../data/residence.csv',sep=";", index_col=False)  
df
# Out:
#         house_type  house_zip_code  house_rooms  house_square_meters  \
# 0      Andelsbolig            6270            3                100.0
# 1            Villa            6430            3                 89.0
# 2       Fritidshus            8410            0                 28.0
# 3       Fritidshus            4942            2                 36.0
# 4            Villa            4900            3                 75.0
# ...            ...             ...          ...                  ...
# 33034        Villa            7742            3                 75.0
# 33035   Fritidshus            6470            3                105.0
# 33036        Villa            9830            2                149.0
# 33037        Villa            6950            6                260.0
# 33038        Villa            6270            6                201.0
#
#        house_year  house_price
# 0            1995           15
# 1            1900           27
# 2            1970           34
# 3            1970           38
# 4            1880           39
# ...           ...          ...
# 33034        1906           75
# 33035        2010           15
# 33036        1950           45
# 33037        2000           41
# 33038        1992           74
#
# [33039 rows x 6 columns]

# %%
# transform the data so that we only calculate predictions on givin ZIP


df = df.loc[df['house_zip_code'] == 3400]

#Data
df_x = df[['house_zip_code', 'house_rooms', 'house_square_meters',
       'house_year']]
#Target
df_y = df[['house_price']]

df_y
#df_x
# Out:
#        house_price
# 245             29
# 303             39
# 751             37
# 772             40
# 1164            36
# ...            ...
# 24267           59
# 24407           22
# 25263           54
# 25534           39
# 27317           47
#
# [117 rows x 1 columns]

# %%
# initialize the linear model
reg = linear_model.LinearRegression()

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.33, random_state=42 )

# %%
# fit scaler on training data
norm = MinMaxScaler().fit(x_train)


# transform training data
x_train_norm = norm.transform(x_train)


# transform testing dataa
x_test_norm = norm.transform(x_test)

# %%
print(x_train_norm)
# Out:
# [[0.         0.11111111 0.18303571 0.01546392]
#  [0.         0.55555556 0.5625     0.92268041]
#  [0.         0.55555556 0.52232143 0.57731959]
#  [0.         0.55555556 0.57589286 0.61340206]
#  [0.         0.55555556 0.62946429 0.71134021]
#  [0.         0.55555556 0.64732143 0.74742268]
#  [0.         0.44444444 0.78125    0.99484536]
#  [0.         0.55555556 0.60714286 0.95360825]
#  [0.         0.33333333 0.31696429 0.71649485]
#  [0.         0.44444444 0.45089286 0.7371134 ]
#  [0.         0.77777778 1.         0.72680412]
#  [0.         0.22222222 0.26785714 0.32474227]
#  [0.         0.33333333 0.35714286 0.91752577]
#  [0.         0.33333333 0.37946429 0.51546392]
#  [0.         0.33333333 0.61607143 0.80412371]
#  [0.         0.22222222 0.04910714 0.99484536]
#  [0.         1.         0.57142857 0.68041237]
#  [0.         0.22222222 0.29910714 0.92783505]
#  [0.         0.22222222 0.22767857 0.97938144]
#  [0.         0.         0.         0.32474227]
#  [0.         0.66666667 0.55803571 0.6185567 ]
#  [0.         0.44444444 0.40625    0.25773196]
#  [0.         0.22222222 0.13839286 0.57731959]
#  [0.         0.33333333 0.23660714 0.70618557]
#  [0.         0.44444444 0.31696429 0.72680412]
#  [0.         0.22222222 0.29910714 0.92783505]
#  [0.         0.22222222 0.20982143 0.83505155]
#  [0.         0.33333333 0.39285714 0.81958763]
#  [0.         0.55555556 0.60714286 0.75257732]
#  [0.         0.44444444 0.46428571 0.72680412]
#  [0.         0.44444444 0.40625    0.71134021]
#  [0.         0.55555556 0.54910714 0.70618557]
#  [0.         0.33333333 0.31696429 0.70103093]
#  [0.         0.22222222 0.61607143 0.99484536]
#  [0.         0.66666667 0.78571429 0.37628866]
#  [0.         0.         0.00892857 0.7371134 ]
#  [0.         0.44444444 0.5625     0.37628866]
#  [0.         0.55555556 0.58035714 0.70103093]
#  [0.         0.44444444 0.37053571 0.61340206]
#  [0.         0.22222222 0.39285714 1.        ]
#  [0.         0.33333333 0.37053571 0.7628866 ]
#  [0.         0.33333333 0.37946429 0.23195876]
#  [0.         0.33333333 0.40625    0.37628866]
#  [0.         0.22222222 0.17857143 0.97938144]
#  [0.         0.55555556 0.61607143 0.69072165]
#  [0.         0.33333333 0.08928571 0.75773196]
#  [0.         0.22222222 0.18303571 0.68556701]
#  [0.         0.22222222 0.26339286 1.        ]
#  [0.         0.55555556 0.50892857 0.72164948]
#  [0.         0.33333333 0.37053571 1.        ]
#  [0.         0.44444444 0.42857143 0.7628866 ]
#  [0.         0.22222222 0.33928571 1.        ]
#  [0.         0.33333333 0.23214286 0.60824742]
#  [0.         0.44444444 0.62946429 0.7628866 ]
#  [0.         0.44444444 0.56696429 1.        ]
#  [0.         0.33333333 0.29017857 1.        ]
#  [0.         0.33333333 0.37053571 0.76804124]
#  [0.         0.33333333 0.29017857 0.56185567]
#  [0.         0.44444444 0.39732143 0.97938144]
#  [0.         0.22222222 0.20089286 0.7371134 ]
#  [0.         0.33333333 0.29017857 0.70103093]
#  [0.         0.33333333 0.39732143 0.78350515]
#  [0.         0.44444444 0.48214286 0.72164948]
#  [0.         0.11111111 0.04910714 0.96391753]
#  [0.         0.33333333 0.21875    0.        ]
#  [0.         0.11111111 0.10714286 0.61340206]
#  [0.         0.22222222 0.32142857 1.        ]
#  [0.         0.11111111 0.30357143 0.45360825]
#  [0.         0.11111111 0.13839286 0.7628866 ]
#  [0.         0.44444444 0.74107143 0.82989691]
#  [0.         0.33333333 0.36160714 0.63402062]
#  [0.         0.44444444 0.33482143 0.78865979]
#  [0.         0.55555556 0.45535714 0.88659794]
#  [0.         0.66666667 0.55803571 0.89175258]
#  [0.         0.77777778 0.58928571 0.43814433]
#  [0.         0.22222222 0.15625    0.56185567]
#  [0.         0.33333333 0.27678571 0.24742268]
#  [0.         0.44444444 0.38839286 0.94845361]]

# %%
print(y_train)
# Out:
#        house_price
# 12847           31
# 6867            44
# 9561            49
# 15099           37
# 1189            44
# ...            ...
# 22215           43
# 3395            49
# 18074           32
# 10339           28
# 21545           37
#
# [78 rows x 1 columns]

# %%
reg.fit(x_train_norm, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
data = [[0, 0.55555556, 0.57589286, 0.61340206]]
testing_df = pd.DataFrame (data, columns = ['house_zip_code','house_rooms', 'house_square_meters', 'house_year'])
testing_df
# result should be 37
# Out:
#    house_zip_code  house_rooms  house_square_meters  house_year
# 0               0     0.555556             0.575893    0.613402

# %%
# predictions
pred = reg.predict(testing_df)
print(pred)
# Out:
# [[41.93582024]
#  [36.81510917]
#  [54.96552656]
#  [15.87235331]
#  [43.4849566 ]
#  [24.48601444]
#  [36.40698873]
#  [29.46281397]
#  [49.34739083]
#  [30.92629723]
#  [25.23286148]
#  [31.43480462]
#  [32.54348399]
#  [43.53961656]
#  [31.48063691]
#  [32.82011903]
#  [65.43420563]
#  [34.55118849]
#  [37.27086114]
#  [59.71428686]
#  [30.61260491]
#  [25.51601649]
#  [39.54693414]
#  [31.89573313]
#  [35.29420242]
#  [43.73392316]
#  [24.28929482]
#  [39.56740566]
#  [19.24776953]
#  [42.80020111]
#  [32.4477651 ]
#  [64.82171281]
#  [37.56976695]
#  [41.86929524]
#  [35.80917712]
#  [19.63361921]
#  [48.93100384]
#  [19.67298419]
#  [20.16574078]]

# %%
y_test
# Out:
#        house_price
# 9548            40
# 1164            36
# 10705           67
# 9412            17
# 2509            51
# 15701           20
# 14048           35
# 18413           31
# 8297            57
# 2866            35
# 8767            26
# 6463            35
# 18715           27
# 21985           39
# 4623            26
# 245             29
# 12115           42
# 24267           59
# 14053           37
# 20611           59
# 12932           23
# 16722           19
# 25534           39
# 2900            44
# 3988            38
# 13263           37
# 7413            17
# 6132            42
# 11047           21
# 5295            27
# 24034           32
# 12553           52
# 14878           43
# 7109            59
# 14049           35
# 9949            11
# 2474            41
# 8148            19
# 23701           92

# %%
print(np.mean((pred - y_test)**2))
# Out:
# house_price    204.135434
# dtype: float64
